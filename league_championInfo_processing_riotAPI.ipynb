# %%
from riotwatcher import LolWatcher, ApiError

key = open('C:/Users/ThinkPad/Desktop/league test code/api_key.txt','r') #reading riot Dev API key 

lol_watcher = LolWatcher('key.read()') 

region = 'na1'
versions = lol_watcher.data_dragon.versions_for_region(region)
item_version = versions['n']['item'] #checking the current patch

current_champ_list = lol_watcher.data_dragon.champions(item_version) #requesting all the champ details from the current patch

print(item_version)
# Out:
# 12.13.1

# %%
#current_champ_list #Large json file so I commented it our

# %%
import pandas as pd
pd.set_option('display.max_columns',None)
#pd.json_normalize(current_champ_list['data'])
pd.DataFrame(current_champ_list['data']) #making a dataframe from the json I recived from the API
# Out:
#                                                     Aatrox  \
# version                                            12.13.1
# id                                                  Aatrox
# key                                                    266
# name                                                Aatrox
# title                                     the Darkin Blade
# blurb    Once honored defenders of Shurima against the ...
# info     {'attack': 8, 'defense': 4, 'magic': 3, 'diffi...
# image    {'full': 'Aatrox.png', 'sprite': 'champion0.pn...
# tags                                       [Fighter, Tank]
# partype                                         Blood Well
# stats    {'hp': 650, 'hpperlevel': 104, 'mp': 0, 'mpper...
#
#                                                       Ahri  \
# version                                            12.13.1
# id                                                    Ahri
# key                                                    103
# name                                                  Ahri
# title                                  the Nine-Tailed Fox
# blurb    Innately connected to the latent power of Rune...
# info     {'attack': 3, 'defense': 4, 'magic': 8, 'diffi...
# image    {'full': 'Ahri.png', 'sprite': 'champion0.png'...
# tags                                      [Mage, Assassin]
# partype                                               Mana
# stats    {'hp': 570, 'hpperlevel': 96, 'mp': 418, 'mppe...
#
#                                                      Akali  \
# version                                            12.13.1
# id                                                   Akali
# key                                                     84
# name                                                 Akali
# title                                   the Rogue Assassin
# blurb    Abandoning the Kinkou Order and her title of t...
# info     {'attack': 5, 'defense': 3, 'magic': 8, 'diffi...
# image    {'full': 'Akali.png', 'sprite': 'champion0.png...
# tags                                            [Assassin]
# partype                                             Energy
# stats    {'hp': 570, 'hpperlevel': 119, 'mp': 200, 'mpp...
#
#                                                     Akshan  \
# version                                            12.13.1
# id                                                  Akshan
# key                                                    166
# name                                                Akshan
# title                                   the Rogue Sentinel
# blurb    Raising an eyebrow in the face of danger, Aksh...
# info     {'attack': 0, 'defense': 0, 'magic': 0, 'diffi...
# image    {'full': 'Akshan.png', 'sprite': 'champion0.pn...
# tags                                  [Marksman, Assassin]
# partype                                               Mana
# stats    {'hp': 630, 'hpperlevel': 104, 'mp': 350, 'mpp...
#
#                                                    Alistar  \
# version                                            12.13.1
# id                                                 Alistar
# key                                                     12
# name                                               Alistar
# title                                         the Minotaur
# blurb    Always a mighty warrior with a fearsome reputa...
# info     {'attack': 6, 'defense': 9, 'magic': 5, 'diffi...
# image    {'full': 'Alistar.png', 'sprite': 'champion0.p...
# tags                                       [Tank, Support]
# partype                                               Mana
# stats    {'hp': 670, 'hpperlevel': 120, 'mp': 350, 'mpp...
#
#                                                      Amumu  \
# version                                            12.13.1
# id                                                   Amumu
# key                                                     32
# name                                                 Amumu
# title                                        the Sad Mummy
# blurb    Legend claims that Amumu is a lonely and melan...
# info     {'attack': 2, 'defense': 6, 'magic': 8, 'diffi...
# image    {'full': 'Amumu.png', 'sprite': 'champion0.png...
# tags                                          [Tank, Mage]
# partype                                               Mana
# stats    {'hp': 685, 'hpperlevel': 89, 'mp': 285, 'mppe...
#
#                                                     Anivia  \
# version                                            12.13.1
# id                                                  Anivia
# key                                                     34
# name                                                Anivia
# title                                      the Cryophoenix
# blurb    Anivia is a benevolent winged spirit who endur...
# info     {'attack': 1, 'defense': 4, 'magic': 10, 'diff...
# image    {'full': 'Anivia.png', 'sprite': 'champion0.pn...
# tags                                       [Mage, Support]
# partype                                               Mana
# stats    {'hp': 550, 'hpperlevel': 96, 'mp': 495, 'mppe...
#
#                                                      Annie  \
# version                                            12.13.1
# id                                                   Annie
# key                                                      1
# name                                                 Annie
# title                                       the Dark Child
# blurb    Dangerous, yet disarmingly precocious, Annie i...
# info     {'attack': 2, 'defense': 3, 'magic': 10, 'diff...
# image    {'full': 'Annie.png', 'sprite': 'champion0.png...
# tags                                                [Mage]
# partype                                               Mana
# stats    {'hp': 594, 'hpperlevel': 102, 'mp': 418, 'mpp...
#
#                                                   Aphelios  \
# version                                            12.13.1
# id                                                Aphelios
# key                                                    523
# name                                              Aphelios
# title                           the Weapon of the Faithful
# blurb    Emerging from moonlight's shadow with weapons ...
# info     {'attack': 6, 'defense': 2, 'magic': 1, 'diffi...
# image    {'full': 'Aphelios.png', 'sprite': 'champion0....
# tags                                            [Marksman]
# partype                                               Mana
# stats    {'hp': 580, 'hpperlevel': 102, 'mp': 348, 'mpp...
#
#                                                       Ashe  \
# version                                            12.13.1
# id                                                    Ashe
# key                                                     22
# name                                                  Ashe
# title                                     the Frost Archer
# blurb    Iceborn warmother of the Avarosan tribe, Ashe ...
# info     {'attack': 7, 'defense': 3, 'magic': 2, 'diffi...
# image    {'full': 'Ashe.png', 'sprite': 'champion0.png'...
# tags                                   [Marksman, Support]
# partype                                               Mana
# stats    {'hp': 640, 'hpperlevel': 101, 'mp': 280, 'mpp...
#
#                                                AurelionSol  \
# version                                            12.13.1
# id                                             AurelionSol
# key                                                    136
# name                                          Aurelion Sol
# title                                      The Star Forger
# blurb    Aurelion Sol once graced the vast emptiness of...
# info     {'attack': 2, 'defense': 3, 'magic': 8, 'diffi...
# image    {'full': 'AurelionSol.png', 'sprite': 'champio...
# tags                                                [Mage]
# partype                                               Mana
# stats    {'hp': 645, 'hpperlevel': 106, 'mp': 350, 'mpp...
#
#                                                       Azir  \
# version                                            12.13.1
# id                                                    Azir
# key                                                    268
# name                                                  Azir
# title                             the Emperor of the Sands
# blurb    Azir was a mortal emperor of Shurima in a far ...
# info     {'attack': 6, 'defense': 3, 'magic': 8, 'diffi...
# image    {'full': 'Azir.png', 'sprite': 'champion0.png'...
# tags                                      [Mage, Marksman]
# partype                                               Mana
# stats    {'hp': 622, 'hpperlevel': 119, 'mp': 480, 'mpp...
#
#                                                       Bard  \
# version                                            12.13.1
# id                                                    Bard
# key                                                    432
# name                                                  Bard
# title                              the Wandering Caretaker
# blurb    A traveler from beyond the stars, Bard is an a...
# info     {'attack': 4, 'defense': 4, 'magic': 5, 'diffi...
# image    {'full': 'Bard.png', 'sprite': 'champion0.png'...
# tags                                       [Support, Mage]
# partype                                               Mana
# stats    {'hp': 630, 'hpperlevel': 103, 'mp': 350, 'mpp...
#
#                                                    Belveth  \
# version                                            12.13.1
# id                                                 Belveth
# key                                                    200
# name                                              Bel'Veth
# title                              the Empress of the Void
# blurb    A nightmarish empress created from the raw mat...
# info     {'attack': 4, 'defense': 2, 'magic': 7, 'diffi...
# image    {'full': 'Belveth.png', 'sprite': 'champion0.p...
# tags                                             [Fighter]
# partype
# stats    {'hp': 610, 'hpperlevel': 99, 'mp': 60, 'mpper...
#
#                                                 Blitzcrank  \
# version                                            12.13.1
# id                                              Blitzcrank
# key                                                     53
# name                                            Blitzcrank
# title                                the Great Steam Golem
# blurb    Blitzcrank is an enormous, near-indestructible...
# info     {'attack': 4, 'defense': 8, 'magic': 5, 'diffi...
# image    {'full': 'Blitzcrank.png', 'sprite': 'champion...
# tags                                       [Tank, Fighter]
# partype                                               Mana
# stats    {'hp': 653, 'hpperlevel': 109, 'mp': 267, 'mpp...
#
#                                                      Brand  \
# version                                            12.13.1
# id                                                   Brand
# key                                                     63
# name                                                 Brand
# title                                the Burning Vengeance
# blurb    Once a tribesman of the icy Freljord named Keg...
# info     {'attack': 2, 'defense': 2, 'magic': 9, 'diffi...
# image    {'full': 'Brand.png', 'sprite': 'champion0.png...
# tags                                                [Mage]
# partype                                               Mana
# stats    {'hp': 590, 'hpperlevel': 102, 'mp': 469, 'mpp...
#
#                                                      Braum  \
# version                                            12.13.1
# id                                                   Braum
# key                                                    201
# name                                                 Braum
# title                            the Heart of the Freljord
# blurb    Blessed with massive biceps and an even bigger...
# info     {'attack': 3, 'defense': 9, 'magic': 4, 'diffi...
# image    {'full': 'Braum.png', 'sprite': 'champion0.png...
# tags                                       [Support, Tank]
# partype                                               Mana
# stats    {'hp': 610, 'hpperlevel': 112, 'mp': 311, 'mpp...
#
#                                                    Caitlyn  \
# version                                            12.13.1
# id                                                 Caitlyn
# key                                                     51
# name                                               Caitlyn
# title                              the Sheriff of Piltover
# blurb    Renowned as its finest peacekeeper, Caitlyn is...
# info     {'attack': 8, 'defense': 2, 'magic': 2, 'diffi...
# image    {'full': 'Caitlyn.png', 'sprite': 'champion0.p...
# tags                                            [Marksman]
# partype                                               Mana
# stats    {'hp': 580, 'hpperlevel': 107, 'mp': 315, 'mpp...
#
#                                                    Camille  \
# version                                            12.13.1
# id                                                 Camille
# key                                                    164
# name                                               Camille
# title                                     the Steel Shadow
# blurb    Weaponized to operate outside the boundaries o...
# info     {'attack': 8, 'defense': 6, 'magic': 3, 'diffi...
# image    {'full': 'Camille.png', 'sprite': 'champion0.p...
# tags                                       [Fighter, Tank]
# partype                                               Mana
# stats    {'hp': 646, 'hpperlevel': 99, 'mp': 339, 'mppe...
#
#                                                 Cassiopeia  \
# version                                            12.13.1
# id                                              Cassiopeia
# key                                                     69
# name                                            Cassiopeia
# title                                the Serpent's Embrace
# blurb    Cassiopeia is a deadly creature bent on manipu...
# info     {'attack': 2, 'defense': 3, 'magic': 9, 'diffi...
# image    {'full': 'Cassiopeia.png', 'sprite': 'champion...
# tags                                                [Mage]
# partype                                               Mana
# stats    {'hp': 630, 'hpperlevel': 104, 'mp': 350, 'mpp...
#
#                                                    Chogath  \
# version                                            12.13.1
# id                                                 Chogath
# key                                                     31
# name                                              Cho'Gath
# title                               the Terror of the Void
# blurb    From the moment Cho'Gath first emerged into th...
# info     {'attack': 3, 'defense': 7, 'magic': 7, 'diffi...
# image    {'full': 'Chogath.png', 'sprite': 'champion0.p...
# tags                                          [Tank, Mage]
# partype                                               Mana
# stats    {'hp': 644, 'hpperlevel': 94, 'mp': 270, 'mppe...
#
#                                                      Corki  \
# version                                            12.13.1
# id                                                   Corki
# key                                                     42
# name                                                 Corki
# title                                the Daring Bombardier
# blurb    The yordle pilot Corki loves two things above ...
# info     {'attack': 8, 'defense': 3, 'magic': 6, 'diffi...
# image    {'full': 'Corki.png', 'sprite': 'champion0.png...
# tags                                            [Marksman]
# partype                                               Mana
# stats    {'hp': 588, 'hpperlevel': 101, 'mp': 350, 'mpp...
#
#                                                     Darius  \
# version                                            12.13.1
# id                                                  Darius
# key                                                    122
# name                                                Darius
# title                                    the Hand of Noxus
# blurb    There is no greater symbol of Noxian might tha...
# info     {'attack': 9, 'defense': 5, 'magic': 1, 'diffi...
# image    {'full': 'Darius.png', 'sprite': 'champion0.pn...
# tags                                       [Fighter, Tank]
# partype                                               Mana
# stats    {'hp': 652, 'hpperlevel': 114, 'mp': 263, 'mpp...
#
#                                                      Diana  \
# version                                            12.13.1
# id                                                   Diana
# key                                                    131
# name                                                 Diana
# title                                    Scorn of the Moon
# blurb    Bearing her crescent moonblade, Diana fights a...
# info     {'attack': 7, 'defense': 6, 'magic': 8, 'diffi...
# image    {'full': 'Diana.png', 'sprite': 'champion0.png...
# tags                                       [Fighter, Mage]
# partype                                               Mana
# stats    {'hp': 640, 'hpperlevel': 109, 'mp': 375, 'mpp...
#
#                                                     Draven  \
# version                                            12.13.1
# id                                                  Draven
# key                                                    119
# name                                                Draven
# title                             the Glorious Executioner
# blurb    In Noxus, warriors known as Reckoners face one...
# info     {'attack': 9, 'defense': 3, 'magic': 1, 'diffi...
# image    {'full': 'Draven.png', 'sprite': 'champion0.pn...
# tags                                            [Marksman]
# partype                                               Mana
# stats    {'hp': 675, 'hpperlevel': 104, 'mp': 360.56, '...
#
#                                                    DrMundo  \
# version                                            12.13.1
# id                                                 DrMundo
# key                                                     36
# name                                             Dr. Mundo
# title                                   the Madman of Zaun
# blurb    Utterly mad, tragically homicidal, and horrify...
# info     {'attack': 5, 'defense': 7, 'magic': 6, 'diffi...
# image    {'full': 'DrMundo.png', 'sprite': 'champion0.p...
# tags                                       [Fighter, Tank]
# partype                                               None
# stats    {'hp': 653, 'hpperlevel': 103, 'mp': 0, 'mpper...
#
#                                                       Ekko  \
# version                                            12.13.1
# id                                                    Ekko
# key                                                    245
# name                                                  Ekko
# title                           the Boy Who Shattered Time
# blurb    A prodigy from the rough streets of Zaun, Ekko...
# info     {'attack': 5, 'defense': 3, 'magic': 7, 'diffi...
# image    {'full': 'Ekko.png', 'sprite': 'champion0.png'...
# tags                                   [Assassin, Fighter]
# partype                                               Mana
# stats    {'hp': 655, 'hpperlevel': 99, 'mp': 280, 'mppe...
#
#                                                      Elise  \
# version                                            12.13.1
# id                                                   Elise
# key                                                     60
# name                                                 Elise
# title                                     the Spider Queen
# blurb    Elise is a deadly predator who dwells in a shu...
# info     {'attack': 6, 'defense': 5, 'magic': 7, 'diffi...
# image    {'full': 'Elise.png', 'sprite': 'champion0.png...
# tags                                       [Mage, Fighter]
# partype                                               Mana
# stats    {'hp': 650, 'hpperlevel': 109, 'mp': 324, 'mpp...
#
#                                                    Evelynn  \
# version                                            12.13.1
# id                                                 Evelynn
# key                                                     28
# name                                               Evelynn
# title                                      Agony's Embrace
# blurb    Within the dark seams of Runeterra, the demon ...
# info     {'attack': 4, 'defense': 2, 'magic': 7, 'diffi...
# image    {'full': 'Evelynn.png', 'sprite': 'champion0.p...
# tags                                      [Assassin, Mage]
# partype                                               Mana
# stats    {'hp': 642, 'hpperlevel': 98, 'mp': 315, 'mppe...
#
#                                                     Ezreal  \
# version                                            12.13.1
# id                                                  Ezreal
# key                                                     81
# name                                                Ezreal
# title                                the Prodigal Explorer
# blurb    A dashing adventurer, unknowingly gifted in th...
# info     {'attack': 7, 'defense': 2, 'magic': 6, 'diffi...
# image    {'full': 'Ezreal.png', 'sprite': 'champion0.pn...
# tags                                      [Marksman, Mage]
# partype                                               Mana
# stats    {'hp': 600, 'hpperlevel': 102, 'mp': 375, 'mpp...
#
#                                               Fiddlesticks  \
# version                                            12.13.1
# id                                            Fiddlesticks
# key                                                      9
# name                                          Fiddlesticks
# title                                     the Ancient Fear
# blurb    Something has awoken in Runeterra. Something a...
# info     {'attack': 2, 'defense': 3, 'magic': 9, 'diffi...
# image    {'full': 'Fiddlesticks.png', 'sprite': 'champi...
# tags                                       [Mage, Support]
# partype                                               Mana
# stats    {'hp': 650.4, 'hpperlevel': 106, 'mp': 500, 'm...
#
#                                                      Fiora  \
# version                                            12.13.1
# id                                                   Fiora
# key                                                    114
# name                                                 Fiora
# title                                    the Grand Duelist
# blurb    The most feared duelist in all Valoran, Fiora ...
# info     {'attack': 10, 'defense': 4, 'magic': 2, 'diff...
# image    {'full': 'Fiora.png', 'sprite': 'champion1.png...
# tags                                   [Fighter, Assassin]
# partype                                               Mana
# stats    {'hp': 620, 'hpperlevel': 99, 'mp': 300, 'mppe...
#
#                                                       Fizz  \
# version                                            12.13.1
# id                                                    Fizz
# key                                                    105
# name                                                  Fizz
# title                                  the Tidal Trickster
# blurb    Fizz is an amphibious yordle, who dwells among...
# info     {'attack': 6, 'defense': 4, 'magic': 7, 'diffi...
# image    {'full': 'Fizz.png', 'sprite': 'champion1.png'...
# tags                                   [Assassin, Fighter]
# partype                                               Mana
# stats    {'hp': 640, 'hpperlevel': 106, 'mp': 317, 'mpp...
#
#                                                      Galio  \
# version                                            12.13.1
# id                                                   Galio
# key                                                      3
# name                                                 Galio
# title                                         the Colossus
# blurb    Outside the gleaming city of Demacia, the ston...
# info     {'attack': 1, 'defense': 10, 'magic': 6, 'diff...
# image    {'full': 'Galio.png', 'sprite': 'champion1.png...
# tags                                          [Tank, Mage]
# partype                                               Mana
# stats    {'hp': 632, 'hpperlevel': 126, 'mp': 500, 'mpp...
#
#                                                  Gangplank  \
# version                                            12.13.1
# id                                               Gangplank
# key                                                     41
# name                                             Gangplank
# title                                the Saltwater Scourge
# blurb    As unpredictable as he is brutal, the dethrone...
# info     {'attack': 7, 'defense': 6, 'magic': 4, 'diffi...
# image    {'full': 'Gangplank.png', 'sprite': 'champion1...
# tags                                             [Fighter]
# partype                                               Mana
# stats    {'hp': 640, 'hpperlevel': 104, 'mp': 280, 'mpp...
#
#                                                      Garen  \
# version                                            12.13.1
# id                                                   Garen
# key                                                     86
# name                                                 Garen
# title                                 The Might of Demacia
# blurb    A proud and noble warrior, Garen fights as one...
# info     {'attack': 7, 'defense': 7, 'magic': 1, 'diffi...
# image    {'full': 'Garen.png', 'sprite': 'champion1.png...
# tags                                       [Fighter, Tank]
# partype                                               None
# stats    {'hp': 690, 'hpperlevel': 98, 'mp': 0, 'mpperl...
#
#                                                       Gnar  \
# version                                            12.13.1
# id                                                    Gnar
# key                                                    150
# name                                                  Gnar
# title                                     the Missing Link
# blurb    Gnar is a primeval yordle whose playful antics...
# info     {'attack': 6, 'defense': 5, 'magic': 5, 'diffi...
# image    {'full': 'Gnar.png', 'sprite': 'champion1.png'...
# tags                                       [Fighter, Tank]
# partype                                               Rage
# stats    {'hp': 580, 'hpperlevel': 79, 'mp': 100, 'mppe...
#
#                                                     Gragas  \
# version                                            12.13.1
# id                                                  Gragas
# key                                                     79
# name                                                Gragas
# title                                    the Rabble Rouser
# blurb    Equal parts jolly and imposing, Gragas is a ma...
# info     {'attack': 4, 'defense': 7, 'magic': 6, 'diffi...
# image    {'full': 'Gragas.png', 'sprite': 'champion1.pn...
# tags                                       [Fighter, Mage]
# partype                                               Mana
# stats    {'hp': 670, 'hpperlevel': 109, 'mp': 400, 'mpp...
#
#                                                     Graves  \
# version                                            12.13.1
# id                                                  Graves
# key                                                    104
# name                                                Graves
# title                                           the Outlaw
# blurb    Malcolm Graves is a renowned mercenary, gamble...
# info     {'attack': 8, 'defense': 5, 'magic': 3, 'diffi...
# image    {'full': 'Graves.png', 'sprite': 'champion1.pn...
# tags                                            [Marksman]
# partype                                               Mana
# stats    {'hp': 625, 'hpperlevel': 106, 'mp': 325, 'mpp...
#
#                                                       Gwen  \
# version                                            12.13.1
# id                                                    Gwen
# key                                                    887
# name                                                  Gwen
# title                              The Hallowed Seamstress
# blurb    A former doll transformed and brought to life ...
# info     {'attack': 7, 'defense': 4, 'magic': 5, 'diffi...
# image    {'full': 'Gwen.png', 'sprite': 'champion1.png'...
# tags                                   [Fighter, Assassin]
# partype                                               Mana
# stats    {'hp': 660, 'hpperlevel': 109, 'mp': 330, 'mpp...
#
#                                                    Hecarim  \
# version                                            12.13.1
# id                                                 Hecarim
# key                                                    120
# name                                               Hecarim
# title                                    the Shadow of War
# blurb    Hecarim is a spectral fusion of man and beast,...
# info     {'attack': 8, 'defense': 6, 'magic': 4, 'diffi...
# image    {'full': 'Hecarim.png', 'sprite': 'champion1.p...
# tags                                       [Fighter, Tank]
# partype                                               Mana
# stats    {'hp': 650, 'hpperlevel': 104, 'mp': 277, 'mpp...
#
#                                               Heimerdinger  \
# version                                            12.13.1
# id                                            Heimerdinger
# key                                                     74
# name                                          Heimerdinger
# title                                 the Revered Inventor
# blurb    A brilliant yet eccentric yordle scientist, Pr...
# info     {'attack': 2, 'defense': 6, 'magic': 8, 'diffi...
# image    {'full': 'Heimerdinger.png', 'sprite': 'champi...
# tags                                       [Mage, Support]
# partype                                               Mana
# stats    {'hp': 558, 'hpperlevel': 101, 'mp': 385, 'mpp...
#
#                                                     Illaoi  \
# version                                            12.13.1
# id                                                  Illaoi
# key                                                    420
# name                                                Illaoi
# title                                 the Kraken Priestess
# blurb    Illaoi's powerful physique is dwarfed only by ...
# info     {'attack': 8, 'defense': 6, 'magic': 3, 'diffi...
# image    {'full': 'Illaoi.png', 'sprite': 'champion1.pn...
# tags                                       [Fighter, Tank]
# partype                                               Mana
# stats    {'hp': 656, 'hpperlevel': 109, 'mp': 300, 'mpp...
#
#                                                     Irelia  \
# version                                            12.13.1
# id                                                  Irelia
# key                                                     39
# name                                                Irelia
# title                                     the Blade Dancer
# blurb    The Noxian occupation of Ionia produced many h...
# info     {'attack': 7, 'defense': 4, 'magic': 5, 'diffi...
# image    {'full': 'Irelia.png', 'sprite': 'champion1.pn...
# tags                                   [Fighter, Assassin]
# partype                                               Mana
# stats    {'hp': 590, 'hpperlevel': 124, 'mp': 350, 'mpp...
#
#                                                      Ivern  \
# version                                            12.13.1
# id                                                   Ivern
# key                                                    427
# name                                                 Ivern
# title                                     the Green Father
# blurb    Ivern Bramblefoot, known to many as the Green ...
# info     {'attack': 3, 'defense': 5, 'magic': 7, 'diffi...
# image    {'full': 'Ivern.png', 'sprite': 'champion1.png...
# tags                                       [Support, Mage]
# partype                                               Mana
# stats    {'hp': 655, 'hpperlevel': 99, 'mp': 450, 'mppe...
#
#                                                      Janna  \
# version                                            12.13.1
# id                                                   Janna
# key                                                     40
# name                                                 Janna
# title                                     the Storm's Fury
# blurb    Armed with the power of Runeterra's gales, Jan...
# info     {'attack': 3, 'defense': 5, 'magic': 7, 'diffi...
# image    {'full': 'Janna.png', 'sprite': 'champion1.png...
# tags                                       [Support, Mage]
# partype                                               Mana
# stats    {'hp': 570, 'hpperlevel': 84, 'mp': 350, 'mppe...
#
#                                                   JarvanIV  \
# version                                            12.13.1
# id                                                JarvanIV
# key                                                     59
# name                                             Jarvan IV
# title                              the Exemplar of Demacia
# blurb    Prince Jarvan, scion of the Lightshield dynast...
# info     {'attack': 6, 'defense': 8, 'magic': 3, 'diffi...
# image    {'full': 'JarvanIV.png', 'sprite': 'champion1....
# tags                                       [Tank, Fighter]
# partype                                               Mana
# stats    {'hp': 640, 'hpperlevel': 104, 'mp': 300, 'mpp...
#
#                                                        Jax  \
# version                                            12.13.1
# id                                                     Jax
# key                                                     24
# name                                                   Jax
# title                                  Grandmaster at Arms
# blurb    Unmatched in both his skill with unique armame...
# info     {'attack': 7, 'defense': 5, 'magic': 7, 'diffi...
# image    {'full': 'Jax.png', 'sprite': 'champion1.png',...
# tags                                   [Fighter, Assassin]
# partype                                               Mana
# stats    {'hp': 685, 'hpperlevel': 99, 'mp': 339, 'mppe...
#
#                                                      Jayce  \
# version                                            12.13.1
# id                                                   Jayce
# key                                                    126
# name                                                 Jayce
# title                             the Defender of Tomorrow
# blurb    Jayce is a brilliant inventor who has pledged ...
# info     {'attack': 8, 'defense': 4, 'magic': 3, 'diffi...
# image    {'full': 'Jayce.png', 'sprite': 'champion1.png...
# tags                                   [Fighter, Marksman]
# partype                                               Mana
# stats    {'hp': 590, 'hpperlevel': 109, 'mp': 375, 'mpp...
#
#                                                       Jhin  \
# version                                            12.13.1
# id                                                    Jhin
# key                                                    202
# name                                                  Jhin
# title                                         the Virtuoso
# blurb    Jhin is a meticulous criminal psychopath who b...
# info     {'attack': 10, 'defense': 2, 'magic': 6, 'diff...
# image    {'full': 'Jhin.png', 'sprite': 'champion1.png'...
# tags                                      [Marksman, Mage]
# partype                                               Mana
# stats    {'hp': 655, 'hpperlevel': 107, 'mp': 300, 'mpp...
#
#                                                       Jinx  \
# version                                            12.13.1
# id                                                    Jinx
# key                                                    222
# name                                                  Jinx
# title                                     the Loose Cannon
# blurb    A manic and impulsive criminal from Zaun, Jinx...
# info     {'attack': 9, 'defense': 2, 'magic': 4, 'diffi...
# image    {'full': 'Jinx.png', 'sprite': 'champion1.png'...
# tags                                            [Marksman]
# partype                                               Mana
# stats    {'hp': 630, 'hpperlevel': 100, 'mp': 245, 'mpp...
#
#                                                      Kaisa  \
# version                                            12.13.1
# id                                                   Kaisa
# key                                                    145
# name                                                Kai'Sa
# title                                 Daughter of the Void
# blurb    Claimed by the Void when she was only a child,...
# info     {'attack': 8, 'defense': 5, 'magic': 3, 'diffi...
# image    {'full': 'Kaisa.png', 'sprite': 'champion1.png...
# tags                                            [Marksman]
# partype                                               Mana
# stats    {'hp': 670, 'hpperlevel': 102, 'mp': 344.88, '...
#
#                                                    Kalista  \
# version                                            12.13.1
# id                                                 Kalista
# key                                                    429
# name                                               Kalista
# title                               the Spear of Vengeance
# blurb    A specter of wrath and retribution, Kalista is...
# info     {'attack': 8, 'defense': 2, 'magic': 4, 'diffi...
# image    {'full': 'Kalista.png', 'sprite': 'champion1.p...
# tags                                            [Marksman]
# partype                                               Mana
# stats    {'hp': 604, 'hpperlevel': 114, 'mp': 300, 'mpp...
#
#                                                      Karma  \
# version                                            12.13.1
# id                                                   Karma
# key                                                     43
# name                                                 Karma
# title                                  the Enlightened One
# blurb    No mortal exemplifies the spiritual traditions...
# info     {'attack': 1, 'defense': 7, 'magic': 8, 'diffi...
# image    {'full': 'Karma.png', 'sprite': 'champion1.png...
# tags                                       [Mage, Support]
# partype                                               Mana
# stats    {'hp': 604, 'hpperlevel': 109, 'mp': 374, 'mpp...
#
#                                                    Karthus  \
# version                                            12.13.1
# id                                                 Karthus
# key                                                     30
# name                                               Karthus
# title                                      the Deathsinger
# blurb    The harbinger of oblivion, Karthus is an undyi...
# info     {'attack': 2, 'defense': 2, 'magic': 10, 'diff...
# image    {'full': 'Karthus.png', 'sprite': 'champion1.p...
# tags                                                [Mage]
# partype                                               Mana
# stats    {'hp': 620, 'hpperlevel': 110, 'mp': 467, 'mpp...
#
#                                                   Kassadin  \
# version                                            12.13.1
# id                                                Kassadin
# key                                                     38
# name                                              Kassadin
# title                                      the Void Walker
# blurb    Cutting a burning swath through the darkest pl...
# info     {'attack': 3, 'defense': 5, 'magic': 8, 'diffi...
# image    {'full': 'Kassadin.png', 'sprite': 'champion1....
# tags                                      [Assassin, Mage]
# partype                                               Mana
# stats    {'hp': 646, 'hpperlevel': 119, 'mp': 400, 'mpp...
#
#                                                   Katarina  \
# version                                            12.13.1
# id                                                Katarina
# key                                                     55
# name                                              Katarina
# title                                   the Sinister Blade
# blurb    Decisive in judgment and lethal in combat, Kat...
# info     {'attack': 4, 'defense': 3, 'magic': 9, 'diffi...
# image    {'full': 'Katarina.png', 'sprite': 'champion1....
# tags                                      [Assassin, Mage]
# partype                                               None
# stats    {'hp': 672, 'hpperlevel': 108, 'mp': 0, 'mpper...
#
#                                                      Kayle  \
# version                                            12.13.1
# id                                                   Kayle
# key                                                     10
# name                                                 Kayle
# title                                        the Righteous
# blurb    Born to a Targonian Aspect at the height of th...
# info     {'attack': 6, 'defense': 6, 'magic': 7, 'diffi...
# image    {'full': 'Kayle.png', 'sprite': 'champion1.png...
# tags                                    [Fighter, Support]
# partype                                               Mana
# stats    {'hp': 670, 'hpperlevel': 92, 'mp': 330, 'mppe...
#
#                                                       Kayn  \
# version                                            12.13.1
# id                                                    Kayn
# key                                                    141
# name                                                  Kayn
# title                                    the Shadow Reaper
# blurb    A peerless practitioner of lethal shadow magic...
# info     {'attack': 10, 'defense': 6, 'magic': 1, 'diff...
# image    {'full': 'Kayn.png', 'sprite': 'champion1.png'...
# tags                                   [Fighter, Assassin]
# partype                                               Mana
# stats    {'hp': 655, 'hpperlevel': 99, 'mp': 410, 'mppe...
#
#                                                     Kennen  \
# version                                            12.13.1
# id                                                  Kennen
# key                                                     85
# name                                                Kennen
# title                             the Heart of the Tempest
# blurb    More than just the lightning-quick enforcer of...
# info     {'attack': 6, 'defense': 4, 'magic': 7, 'diffi...
# image    {'full': 'Kennen.png', 'sprite': 'champion1.pn...
# tags                                      [Mage, Marksman]
# partype                                             Energy
# stats    {'hp': 611, 'hpperlevel': 98, 'mp': 200, 'mppe...
#
#                                                     Khazix  \
# version                                            12.13.1
# id                                                  Khazix
# key                                                    121
# name                                               Kha'Zix
# title                                       the Voidreaver
# blurb    The Void grows, and the Void adapts—in none of...
# info     {'attack': 9, 'defense': 4, 'magic': 3, 'diffi...
# image    {'full': 'Khazix.png', 'sprite': 'champion2.pn...
# tags                                            [Assassin]
# partype                                               Mana
# stats    {'hp': 643, 'hpperlevel': 99, 'mp': 327, 'mppe...
#
#                                                    Kindred  \
# version                                            12.13.1
# id                                                 Kindred
# key                                                    203
# name                                               Kindred
# title                                  The Eternal Hunters
# blurb    Separate, but never parted, Kindred represents...
# info     {'attack': 8, 'defense': 2, 'magic': 2, 'diffi...
# image    {'full': 'Kindred.png', 'sprite': 'champion2.p...
# tags                                            [Marksman]
# partype                                               Mana
# stats    {'hp': 610, 'hpperlevel': 99, 'mp': 300, 'mppe...
#
#                                                       Kled  \
# version                                            12.13.1
# id                                                    Kled
# key                                                    240
# name                                                  Kled
# title                            the Cantankerous Cavalier
# blurb    A warrior as fearless as he is ornery, the yor...
# info     {'attack': 8, 'defense': 2, 'magic': 2, 'diffi...
# image    {'full': 'Kled.png', 'sprite': 'champion2.png'...
# tags                                       [Fighter, Tank]
# partype                                            Courage
# stats    {'hp': 410, 'hpperlevel': 84, 'mp': 100, 'mppe...
#
#                                                     KogMaw  \
# version                                            12.13.1
# id                                                  KogMaw
# key                                                     96
# name                                               Kog'Maw
# title                               the Mouth of the Abyss
# blurb    Belched forth from a rotting Void incursion de...
# info     {'attack': 8, 'defense': 2, 'magic': 5, 'diffi...
# image    {'full': 'KogMaw.png', 'sprite': 'champion2.pn...
# tags                                      [Marksman, Mage]
# partype                                               Mana
# stats    {'hp': 635, 'hpperlevel': 99, 'mp': 325, 'mppe...
#
#                                                    Leblanc  \
# version                                            12.13.1
# id                                                 Leblanc
# key                                                      7
# name                                               LeBlanc
# ...
# info     {'attack': 2, 'defense': 2, 'magic': 10, 'diff...
# image    {'full': 'Velkoz.png', 'sprite': 'champion4.pn...
# tags                                                [Mage]
# partype                                               Mana
# stats    {'hp': 590, 'hpperlevel': 102, 'mp': 469, 'mpp...
#
#                                                        Vex  \
# version                                            12.13.1
# id                                                     Vex
# key                                                    711
# name                                                   Vex
# title                                         the Gloomist
# blurb    In the black heart of the Shadow Isles, a lone...
# info     {'attack': 0, 'defense': 0, 'magic': 0, 'diffi...
# image    {'full': 'Vex.png', 'sprite': 'champion4.png',...
# tags                                                [Mage]
# partype                                               Mana
# stats    {'hp': 590, 'hpperlevel': 104, 'mp': 490, 'mpp...
#
#                                                         Vi  \
# version                                            12.13.1
# id                                                      Vi
# key                                                    254
# name                                                    Vi
# title                                the Piltover Enforcer
# blurb    Once a criminal from the mean streets of Zaun,...
# info     {'attack': 8, 'defense': 5, 'magic': 3, 'diffi...
# image    {'full': 'Vi.png', 'sprite': 'champion4.png', ...
# tags                                   [Fighter, Assassin]
# partype                                               Mana
# stats    {'hp': 655, 'hpperlevel': 99, 'mp': 295, 'mppe...
#
#                                                      Viego  \
# version                                            12.13.1
# id                                                   Viego
# key                                                    234
# name                                                 Viego
# title                                      The Ruined King
# blurb    Once ruler of a long-lost kingdom, Viego peris...
# info     {'attack': 6, 'defense': 4, 'magic': 2, 'diffi...
# image    {'full': 'Viego.png', 'sprite': 'champion4.png...
# tags                                   [Assassin, Fighter]
# partype                                               None
# stats    {'hp': 630, 'hpperlevel': 109, 'mp': 10000, 'm...
#
#                                                     Viktor  \
# version                                            12.13.1
# id                                                  Viktor
# key                                                    112
# name                                                Viktor
# title                                   the Machine Herald
# blurb    The herald of a new age of technology, Viktor ...
# info     {'attack': 2, 'defense': 4, 'magic': 10, 'diff...
# image    {'full': 'Viktor.png', 'sprite': 'champion4.pn...
# tags                                                [Mage]
# partype                                               Mana
# stats    {'hp': 600, 'hpperlevel': 104, 'mp': 405, 'mpp...
#
#                                                   Vladimir  \
# version                                            12.13.1
# id                                                Vladimir
# key                                                      8
# name                                              Vladimir
# title                                   the Crimson Reaper
# blurb    A fiend with a thirst for mortal blood, Vladim...
# info     {'attack': 2, 'defense': 6, 'magic': 8, 'diffi...
# image    {'full': 'Vladimir.png', 'sprite': 'champion4....
# tags                                                [Mage]
# partype                                       Crimson Rush
# stats    {'hp': 607, 'hpperlevel': 110, 'mp': 2, 'mpper...
#
#                                                   Volibear  \
# version                                            12.13.1
# id                                                Volibear
# key                                                    106
# name                                              Volibear
# title                                 the Relentless Storm
# blurb    To those who still revere him, the Volibear is...
# info     {'attack': 7, 'defense': 7, 'magic': 4, 'diffi...
# image    {'full': 'Volibear.png', 'sprite': 'champion4....
# tags                                       [Fighter, Tank]
# partype                                               Mana
# stats    {'hp': 650, 'hpperlevel': 104, 'mp': 350, 'mpp...
#
#                                                    Warwick  \
# version                                            12.13.1
# id                                                 Warwick
# key                                                     19
# name                                               Warwick
# title                            the Uncaged Wrath of Zaun
# blurb    Warwick is a monster who hunts the gray alleys...
# info     {'attack': 9, 'defense': 5, 'magic': 3, 'diffi...
# image    {'full': 'Warwick.png', 'sprite': 'champion4.p...
# tags                                       [Fighter, Tank]
# partype                                               Mana
# stats    {'hp': 620, 'hpperlevel': 99, 'mp': 280, 'mppe...
#
#                                                      Xayah  \
# version                                            12.13.1
# id                                                   Xayah
# key                                                    498
# name                                                 Xayah
# title                                            the Rebel
# blurb    Deadly and precise, Xayah is a vastayan revolu...
# info     {'attack': 10, 'defense': 6, 'magic': 1, 'diff...
# image    {'full': 'Xayah.png', 'sprite': 'champion4.png...
# tags                                            [Marksman]
# partype                                               Mana
# stats    {'hp': 660, 'hpperlevel': 102, 'mp': 340, 'mpp...
#
#                                                     Xerath  \
# version                                            12.13.1
# id                                                  Xerath
# key                                                    101
# name                                                Xerath
# title                                  the Magus Ascendant
# blurb    Xerath is an Ascended Magus of ancient Shurima...
# info     {'attack': 1, 'defense': 3, 'magic': 10, 'diff...
# image    {'full': 'Xerath.png', 'sprite': 'champion4.pn...
# tags                                                [Mage]
# partype                                               Mana
# stats    {'hp': 596, 'hpperlevel': 106, 'mp': 459, 'mpp...
#
#                                                    XinZhao  \
# version                                            12.13.1
# id                                                 XinZhao
# key                                                      5
# name                                              Xin Zhao
# title                             the Seneschal of Demacia
# blurb    Xin Zhao is a resolute warrior loyal to the ru...
# info     {'attack': 8, 'defense': 6, 'magic': 3, 'diffi...
# image    {'full': 'XinZhao.png', 'sprite': 'champion4.p...
# tags                                   [Fighter, Assassin]
# partype                                               Mana
# stats    {'hp': 640, 'hpperlevel': 106, 'mp': 274, 'mpp...
#
#                                                      Yasuo  \
# version                                            12.13.1
# id                                                   Yasuo
# key                                                    157
# name                                                 Yasuo
# title                                       the Unforgiven
# blurb    An Ionian of deep resolve, Yasuo is an agile s...
# info     {'attack': 8, 'defense': 4, 'magic': 4, 'diffi...
# image    {'full': 'Yasuo.png', 'sprite': 'champion5.png...
# tags                                   [Fighter, Assassin]
# partype                                               Flow
# stats    {'hp': 590, 'hpperlevel': 101, 'mp': 100, 'mpp...
#
#                                                       Yone  \
# version                                            12.13.1
# id                                                    Yone
# key                                                    777
# name                                                  Yone
# title                                      the Unforgotten
# blurb    In life, he was Yone—half-brother of Yasuo, an...
# info     {'attack': 8, 'defense': 4, 'magic': 4, 'diffi...
# image    {'full': 'Yone.png', 'sprite': 'champion5.png'...
# tags                                   [Assassin, Fighter]
# partype                                               Flow
# stats    {'hp': 620, 'hpperlevel': 99, 'mp': 500, 'mppe...
#
#                                                     Yorick  \
# version                                            12.13.1
# id                                                  Yorick
# key                                                     83
# name                                                Yorick
# title                                    Shepherd of Souls
# blurb    The last survivor of a long-forgotten religiou...
# info     {'attack': 6, 'defense': 6, 'magic': 4, 'diffi...
# image    {'full': 'Yorick.png', 'sprite': 'champion5.pn...
# tags                                       [Fighter, Tank]
# partype                                               Mana
# stats    {'hp': 650, 'hpperlevel': 114, 'mp': 300, 'mpp...
#
#                                                      Yuumi  \
# version                                            12.13.1
# id                                                   Yuumi
# key                                                    350
# name                                                 Yuumi
# title                                      the Magical Cat
# blurb    A magical cat from Bandle City, Yuumi was once...
# info     {'attack': 5, 'defense': 1, 'magic': 8, 'diffi...
# image    {'full': 'Yuumi.png', 'sprite': 'champion5.png...
# tags                                       [Support, Mage]
# partype                                               Mana
# stats    {'hp': 550, 'hpperlevel': 84, 'mp': 400, 'mppe...
#
#                                                        Zac  \
# version                                            12.13.1
# id                                                     Zac
# key                                                    154
# name                                                   Zac
# title                                    the Secret Weapon
# blurb    Zac is the product of a toxic spill that ran t...
# info     {'attack': 3, 'defense': 7, 'magic': 7, 'diffi...
# image    {'full': 'Zac.png', 'sprite': 'champion5.png',...
# tags                                       [Tank, Fighter]
# partype                                               None
# stats    {'hp': 685, 'hpperlevel': 109, 'mp': 0, 'mpper...
#
#                                                        Zed  \
# version                                            12.13.1
# id                                                     Zed
# key                                                    238
# name                                                   Zed
# title                                the Master of Shadows
# blurb    Utterly ruthless and without mercy, Zed is the...
# info     {'attack': 9, 'defense': 2, 'magic': 1, 'diffi...
# image    {'full': 'Zed.png', 'sprite': 'champion5.png',...
# tags                                            [Assassin]
# partype                                             Energy
# stats    {'hp': 654, 'hpperlevel': 99, 'mp': 200, 'mppe...
#
#                                                       Zeri  \
# version                                            12.13.1
# id                                                    Zeri
# key                                                    221
# name                                                  Zeri
# title                                    The Spark of Zaun
# blurb    A headstrong, spirited young woman from Zaun's...
# info     {'attack': 8, 'defense': 5, 'magic': 3, 'diffi...
# image    {'full': 'Zeri.png', 'sprite': 'champion5.png'...
# tags                                            [Marksman]
# partype                                               Mana
# stats    {'hp': 600, 'hpperlevel': 109, 'mp': 250, 'mpp...
#
#                                                      Ziggs  \
# version                                            12.13.1
# id                                                   Ziggs
# key                                                    115
# name                                                 Ziggs
# title                               the Hexplosives Expert
# blurb    With a love of big bombs and short fuses, the ...
# info     {'attack': 2, 'defense': 4, 'magic': 9, 'diffi...
# image    {'full': 'Ziggs.png', 'sprite': 'champion5.png...
# tags                                                [Mage]
# partype                                               Mana
# stats    {'hp': 606, 'hpperlevel': 106, 'mp': 480, 'mpp...
#
#                                                     Zilean  \
# version                                            12.13.1
# id                                                  Zilean
# key                                                     26
# name                                                Zilean
# title                                     the Chronokeeper
# blurb    Once a powerful Icathian mage, Zilean became o...
# info     {'attack': 2, 'defense': 5, 'magic': 8, 'diffi...
# image    {'full': 'Zilean.png', 'sprite': 'champion5.pn...
# tags                                       [Support, Mage]
# partype                                               Mana
# stats    {'hp': 574, 'hpperlevel': 96, 'mp': 452, 'mppe...
#
#                                                        Zoe  \
# version                                            12.13.1
# id                                                     Zoe
# key                                                    142
# name                                                   Zoe
# title                               the Aspect of Twilight
# blurb    As the embodiment of mischief, imagination, an...
# info     {'attack': 1, 'defense': 7, 'magic': 8, 'diffi...
# image    {'full': 'Zoe.png', 'sprite': 'champion5.png',...
# tags                                       [Mage, Support]
# partype                                               Mana
# stats    {'hp': 630, 'hpperlevel': 106, 'mp': 425, 'mpp...
#
#                                                       Zyra
# version                                            12.13.1
# id                                                    Zyra
# key                                                    143
# name                                                  Zyra
# title                                   Rise of the Thorns
# blurb    Born in an ancient, sorcerous catastrophe, Zyr...
# info     {'attack': 4, 'defense': 3, 'magic': 8, 'diffi...
# image    {'full': 'Zyra.png', 'sprite': 'champion5.png'...
# tags                                       [Mage, Support]
# partype                                               Mana
# stats    {'hp': 574, 'hpperlevel': 93, 'mp': 418, 'mppe...

# %%
df = pd.DataFrame(current_champ_list['data'])
df.T
df2 = df.T #I wanted to use the rows as columns

# %%
#Exporting them as csv
df.to_csv('LOLChampData_v1.csv', encoding='utf-8')
df2.to_csv('LOLChampData_v2.csv', encoding='utf-8')

# %%
pd.DataFrame(df2['stats']) #just wanna see the stats for all champs
# Out:
#                                                      stats
# Aatrox   {'hp': 650, 'hpperlevel': 104, 'mp': 0, 'mpper...
# Ahri     {'hp': 570, 'hpperlevel': 96, 'mp': 418, 'mppe...
# Akali    {'hp': 570, 'hpperlevel': 119, 'mp': 200, 'mpp...
# Akshan   {'hp': 630, 'hpperlevel': 104, 'mp': 350, 'mpp...
# Alistar  {'hp': 670, 'hpperlevel': 120, 'mp': 350, 'mpp...
# ...                                                    ...
# Zeri     {'hp': 600, 'hpperlevel': 109, 'mp': 250, 'mpp...
# Ziggs    {'hp': 606, 'hpperlevel': 106, 'mp': 480, 'mpp...
# Zilean   {'hp': 574, 'hpperlevel': 96, 'mp': 452, 'mppe...
# Zoe      {'hp': 630, 'hpperlevel': 106, 'mp': 425, 'mpp...
# Zyra     {'hp': 574, 'hpperlevel': 93, 'mp': 418, 'mppe...
#
# [161 rows x 1 columns]

# %%
pd.DataFrame(df2['tags']) #I wanna see the roles assigned to each champ
# Out:
#                          tags
# Aatrox        [Fighter, Tank]
# Ahri         [Mage, Assassin]
# Akali              [Assassin]
# Akshan   [Marksman, Assassin]
# Alistar       [Tank, Support]
# ...                       ...
# Zeri               [Marksman]
# Ziggs                  [Mage]
# Zilean        [Support, Mage]
# Zoe           [Mage, Support]
# Zyra          [Mage, Support]
#
# [161 rows x 1 columns]

# %%
roles = pd.DataFrame(df2['tags'])
roles.to_csv('LOLChampRoles.csv', encoding='utf-8') #Exporting roles as a csv

# %%
champData= pd.read_csv("LOLChampRoles.csv",error_bad_lines=False)
champData['tags']
# Out:
# 0           ['Fighter', 'Tank']
# 1          ['Mage', 'Assassin']
# 2                  ['Assassin']
# 3      ['Marksman', 'Assassin']
# 4           ['Tank', 'Support']
#                  ...
# 156                ['Marksman']
# 157                    ['Mage']
# 158         ['Support', 'Mage']
# 159         ['Mage', 'Support']
# 160         ['Mage', 'Support']
# Name: tags, Length: 161, dtype: object

# %%
champData["tags"].value_counts()
# Out:
# ['Fighter', 'Tank']         22
# ['Marksman']                15
# ['Mage']                    15
# ['Fighter', 'Assassin']     13
# ['Mage', 'Support']         12
# ['Tank', 'Fighter']         11
# ['Support', 'Mage']         10
# ['Assassin', 'Fighter']      8
# ['Marksman', 'Assassin']     6
# ['Assassin']                 5
# ['Assassin', 'Mage']         5
# ['Fighter']                  4
# ['Fighter', 'Mage']          4
# ['Marksman', 'Mage']         4
# ['Tank', 'Mage']             4
# ['Tank', 'Support']          4
# ['Mage', 'Fighter']          3
# ['Mage', 'Assassin']         3
# ['Mage', 'Marksman']         2
# ['Support', 'Fighter']       2
# ['Marksman', 'Support']      2
# ['Support', 'Tank']          2
# ['Support']                  1
# ['Tank']                     1
# ['Fighter', 'Marksman']      1
# ['Fighter', 'Support']       1
# ['Support', 'Assassin']      1
# Name: tags, dtype: int64

# %%
champData["tags"] = champData["tags"].apply(eval)

# %%
#Counting the number of champs in a role 
champ = {}
for i in champData["tags"]:
    for j in i:
        if j not in champ:
            champ[j] = 1
        else:
            champ[j] += 1

# %%
champ
# Out:
# {'Fighter': 69,
#  'Tank': 44,
#  'Mage': 62,
#  'Assassin': 41,
#  'Marksman': 30,
#  'Support': 35}

# %%
champList = champ.items()
champList = sorted(champList) 
x, y = zip(*champList) 
fig, ax = plt.subplots(figsize = (10,10))
ax.set_ylabel("Number of champion", size = 12)
ax.set_title("Assigned Roles", size = 14)
ax.bar(x, y)
# Out:
# <BarContainer object of 6 artists>
